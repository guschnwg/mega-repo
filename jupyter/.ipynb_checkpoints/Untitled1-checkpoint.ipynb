# %%
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials

# credentials
cid =''
secret = ''
username = 'guschnwg'
scope = 'user-library-read playlist-read-private playlist-read-collaborative playlist-modify-private playlist-modify-public'
redirect_uri='http://localhost:8888/callback'

# access user
client_credentials_manager = spotipy.oauth2.SpotifyOAuth(
    scope=scope,
    username=username,
    client_id=cid,
    client_secret=secret,
    redirect_uri=redirect_uri,
    open_browser=False,
)
spotify = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

def get_all(results, key='items'):
    all_stuff = results[key]
    while results['next']:
        results = spotify.next(results)
        all_stuff.extend(results[key])
        
    return all_stuff

# %%
playlists = spotify.user_playlists('guschnwg')["items"]

# %%
the_one = next(playlist for playlist in playlists if playlist["name"] == "Na estrada com a atual ☀️🌴🌊")
items = get_all(spotify.playlist_items(the_one["id"], fields="*"))

# %%
all_genres = {}
for song in items:
    artists = song["track"]["artists"]
    for artist in artists:
        genres = spotify.artist(artist["id"])["genres"]
        for genre in genres:
            if genre not in all_genres:
                all_genres[genre] = []
            
            all_genres[genre].append(song)

# %%
sorted_by_count = sorted(all_genres.items(), key=lambda item: len(item[1]), reverse=True)
sorted_by_count = dict(sorted_by_count)

# %%
for genre in sorted_by_count:
    print(f"{genre} {len(sorted_by_count[genre])}")
# Out:
# pop 128
# dance pop 98
# funk carioca 88
# pop nacional 55
# pop lgbtq+ brasileira 49
# funk pop 37
# funk rj 30
# post-teen pop 26
# edm 22
# nova mpb 21
# pagode 19
# pagode baiano 19
# axe 18
# tropical house 18
# mpb 18
# electropop 15
# pop dance 15
# urbano latino 14
# reggaeton 14
# urban contemporary 14
# neo mellow 14
# latin pop 13
# indie pop 13
# arrocha 13
# metropopolis 12
# pop rap 11
# r&b 10
# pop rock 10
# lilith 10
# art pop 10
# modern rock 8
# canadian indie 8
# permanent wave 8
# transpop 8
# samba reggae 8
# forro 7
# sertanejo pop 7
# neo soul 7
# uk pop 7
# canadian pop 6
# latin hip hop 6
# rock 6
# tecnobrega 6
# barbadian pop 6
# indie poptimism 6
# sertanejo universitario 6
# rap 5
# rap latina 5
# trap latino 5
# reggaeton colombiano 5
# deboxe 5
# musica popular paraense 5
# electro house 5
# quiet storm 5
# r&b en espanol 5
# progressive house 5
# boy band 5
# afrofuturismo brasileiro 5
# dominican pop 4
# colombian pop 4
# latin rock 4
# indie rock 4
# nova musica pernambucana 4
# alt z 4
# europop 4
# funk 4
# brazilian hip hop 4
# gauze pop 4
# pop rock brasileiro 4
# australian pop 4
# funk 150 bpm 3
# hip hop 3
# funk mtg 3
# viral pop 3
# cumbia 3
# latin alternative 3
# pop electronico 3
# tropical alternativo 3
# brazilian indie 1
# dembow 1
# rap dominicano 1
# argentine alternative rock 1
# electronica argentina 1
# trap argentino 1
# azonto 1
# soca 1
# musica goiana 1
# rock goiano 1
# modern indie pop 1
# bedroom pop 1
# electra 1
# vapor soul 1
# wonky 1
# la pop 1
# deep tech house 1
# brazilian soul 1
# pop nacional antigas 1
# brazilian house 1
# glam rock 1
# mellow gold 1
# australian dance 1
# australian electropop 1
# serbian electronic 1
# rap feminino nacional 1
# musica indigena brasileira 1
# dutch trance 1
# progressive trance 1
# austrian pop 1
# deep house 1
# new french touch 1
# la indie 1
# electronica 1
# experimental pop 1
# microhouse 1
# minimal techno 1
# nigerian pop 1
# uk alternative pop 1
# funk consciente 1
# funk mandelao 1
# funk viral 1

# %%
tracks = [item["track"] for item in items]

import numpy as np

all_features = []
for chunk in np.array_split(tracks, 50):
    features = spotify.audio_features([track["id"] for track in chunk])
    for feature in features:
        track = next(track for track in chunk if track["id"] == feature["id"])
        track["audio_features"] = feature
# Out:
# {'album': {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6tzRZ39aZlNqlUzQlkuhDV'},
#     'href': 'https://api.spotify.com/v1/artists/6tzRZ39aZlNqlUzQlkuhDV',
#     'id': '6tzRZ39aZlNqlUzQlkuhDV',
#     'name': 'Pabllo Vittar',
#     'type': 'artist',
#     'uri': 'spotify:artist:6tzRZ39aZlNqlUzQlkuhDV'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7ecRwFks8F2vYad383BkKf'},
#     'href': 'https://api.spotify.com/v1/artists/7ecRwFks8F2vYad383BkKf',
#     'id': '7ecRwFks8F2vYad383BkKf',
#     'name': 'Rennan da Penha',
#     'type': 'artist',
#     'uri': 'spotify:artist:7ecRwFks8F2vYad383BkKf'}],
#   'available_markets': ['BR'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3fVQZx5dGqz2QmOeScqhMM'},
#   'href': 'https://api.spotify.com/v1/albums/3fVQZx5dGqz2QmOeScqhMM',
#   'id': '3fVQZx5dGqz2QmOeScqhMM',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273f2705de429424225622745b9',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02f2705de429424225622745b9',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851f2705de429424225622745b9',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Number One',
#   'release_date': '2021-11-29',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:3fVQZx5dGqz2QmOeScqhMM'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6tzRZ39aZlNqlUzQlkuhDV'},
#    'href': 'https://api.spotify.com/v1/artists/6tzRZ39aZlNqlUzQlkuhDV',
#    'id': '6tzRZ39aZlNqlUzQlkuhDV',
#    'name': 'Pabllo Vittar',
#    'type': 'artist',
#    'uri': 'spotify:artist:6tzRZ39aZlNqlUzQlkuhDV'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7ecRwFks8F2vYad383BkKf'},
#    'href': 'https://api.spotify.com/v1/artists/7ecRwFks8F2vYad383BkKf',
#    'id': '7ecRwFks8F2vYad383BkKf',
#    'name': 'Rennan da Penha',
#    'type': 'artist',
#    'uri': 'spotify:artist:7ecRwFks8F2vYad383BkKf'}],
#  'available_markets': ['BR'],
#  'disc_number': 1,
#  'duration_ms': 182054,
#  'episode': False,
#  'explicit': False,
#  'external_ids': {'isrc': 'BCM112100080'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/7ysjfyBKvnO2iX1vWqhn4X'},
#  'href': 'https://api.spotify.com/v1/tracks/7ysjfyBKvnO2iX1vWqhn4X',
#  'id': '7ysjfyBKvnO2iX1vWqhn4X',
#  'is_local': False,
#  'name': 'Number One',
#  'popularity': 42,
#  'preview_url': 'https://p.scdn.co/mp3-preview/6c31218596edb62d99c2cc97babe0cf501645c2c?cid=f90163beae7c45e5822c6701cd5031b0',
#  'track': True,
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:7ysjfyBKvnO2iX1vWqhn4X',
#  'audio_features': {'danceability': 0.755,
#   'energy': 0.899,
#   'key': 7,
#   'loudness': -3.748,
#   'mode': 1,
#   'speechiness': 0.202,
#   'acousticness': 0.0649,
#   'instrumentalness': 0,
#   'liveness': 0.2,
#   'valence': 0.493,
#   'tempo': 139.91,
#   'type': 'audio_features',
#   'id': '7ysjfyBKvnO2iX1vWqhn4X',
#   'uri': 'spotify:track:7ysjfyBKvnO2iX1vWqhn4X',
#   'track_href': 'https://api.spotify.com/v1/tracks/7ysjfyBKvnO2iX1vWqhn4X',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7ysjfyBKvnO2iX1vWqhn4X',
#   'duration_ms': 182055,
#   'time_signature': 4}}

# %%
data = [{
    "name": track["name"],
    "danceability": track["audio_features"]["danceability"],
    "speechiness": track["audio_features"]["danceability"]
} for track in tracks]

# %%
import pandas as pd

df = pd.DataFrame(data)
df..plot.scatter(x='danceability', y='speechiness', c='DarkBlue')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 import pandas as pd
#       3 df = pd.DataFrame(data)
#       4 df.scatter.plot()
#
# ModuleNotFoundError: No module named 'pandas'
